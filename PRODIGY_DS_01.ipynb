# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('asthma_disease_data.csv')

# %%
df.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0       5034   63       0          1               0  15.848744        0
# 1       5035   26       1          2               2  22.757042        0
# 2       5036   57       0          2               1  18.395396        0
# 3       5037   40       1          2               1  38.515278        0
# 4       5038   61       0          0               3  19.283802        0
#
#    PhysicalActivity  DietQuality  SleepQuality  ...  LungFunctionFEV1  \
# 0          0.894448     5.488696      8.701003  ...          1.369051
# 1          5.897329     6.341014      5.153966  ...          2.197767
# 2          6.739367     9.196237      6.840647  ...          1.698011
# 3          1.404503     5.826532      4.253036  ...          3.032037
# 4          4.604493     3.127048      9.625799  ...          3.470589
#
#    LungFunctionFVC  Wheezing  ShortnessOfBreath  ChestTightness  Coughing  \
# ...

# %% [markdown]
# # Histogram

# %%
numeric_columns = df.select_dtypes(include='number').columns

df[numeric_columns].hist(figsize=(15, 10))
plt.tight_layout()
plt.show()

# %% [markdown]
# # Bar Chart

# %%
avg_bmi_by_gender = df.groupby('Gender')['BMI'].mean()

avg_bmi_by_gender.plot(kind='bar', figsize=(8, 6))
plt.xlabel('Gender')
plt.ylabel('Average BMI')
plt.title('Average BMI by Gender')
plt.xticks(ticks=[0, 1], labels=['Male', 'Female'], rotation=0)  
plt.show()

# %%
avg_bmi_by_diagnosis = df.groupby('Diagnosis')['BMI'].mean()

# %%
avg_bmi_by_diagnosis.plot(kind='bar', figsize=(8, 6))
plt.xlabel('Diagnosis')
plt.ylabel('Average BMI')
plt.title('Average BMI by Diagnosis')
plt.xticks(ticks=avg_bmi_by_diagnosis.index, labels=['No Diagnosis', 'Diagnosis'], rotation=0)
plt.show()
